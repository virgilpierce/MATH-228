# %%
import pandas as pd

# %%
schedule = pd.read_csv("MATH 228 Schedule - Fall 2020.csv", names = ['Day', 'Date', 
                                                                       'Meeting', 'Topic'],
                      skiprows=[0])
schedule = schedule.drop(46)
schedule
# Out:
#           Day   Date                 Meeting  \
# 0      Monday   8/24                    Zoom
# 1   Wednesday   8/26                    Zoom
# 2      Friday   8/28                    Zoom
# 3      Monday   8/31                    Zoom
# 4   Wednesday    9/2                    Zoom
# 5      Friday    9/4                   Video
# 6      Monday    9/7               Labor Day
# 7   Wednesday    9/9                    Zoom
# 8      Friday   9/11                   Video
# 9      Monday   9/14                    Zoom
# 10  Wednesday   9/16                    Zoom
# 11     Friday   9/18                   Video
# 12     Monday   9/21                   Zoom
# 13  Wednesday   9/23                    Zoom
# 14     Friday   9/25                   Video
# 15     Monday   9/28                    Zoom
# 16  Wednesday   9/30                    Zoom
# 17     Friday   10/2                   Video
# 18     Monday   10/5                    Zoom
# 19  Wednesday   10/7                   Video
# ...

# %%
schedule.head(8)
# Out:
#          Day  Date    Meeting                                    Topic
# 0     Monday  8/24       Zoom  Course Introduction - What are we doing
# 1  Wednesday  8/26       Zoom                                   Graphs
# 2     Friday  8/28       Zoom   Python for Graphs; Sets; and Functions
# 3     Monday  8/31       Zoom                             Graphs Again
# 4  Wednesday   9/2       Zoom                                 Coloring
# 5     Friday   9/4      Video                      Activity - Coloring
# 6     Monday   9/7  Labor Day                                 No Class
# 7  Wednesday   9/9       Zoom                                    Recap

# %%
schedule.loc[1, 'Topic'] = 'Introduction Day 2'
schedule.loc[2, 'Topic'] = 'Graphs'
schedule.loc[3, 'Topic'] = 'Graphs Day 2'
schedule.loc[4, 'Topic'] = 'Sets and Functions'
schedule.loc[7, 'Topic'] = 'Graphs Again'
schedule.loc[4, 'Meeting'] = 'Activity Day'
schedule
# Out:
#           Day   Date                 Meeting  \
# 0      Monday   8/24                    Zoom
# 1   Wednesday   8/26                    Zoom
# 2      Friday   8/28                    Zoom
# 3      Monday   8/31                    Zoom
# 4   Wednesday    9/2            Activity Day
# 5      Friday    9/4                   Video
# 6      Monday    9/7               Labor Day
# 7   Wednesday    9/9                    Zoom
# 8      Friday   9/11                   Video
# 9      Monday   9/14                    Zoom
# 10  Wednesday   9/16                    Zoom
# 11     Friday   9/18                   Video
# 12     Monday   9/21                   Zoom
# 13  Wednesday   9/23                    Zoom
# 14     Friday   9/25                   Video
# 15     Monday   9/28                    Zoom
# 16  Wednesday   9/30                    Zoom
# 17     Friday   10/2                   Video
# 18     Monday   10/5                    Zoom
# 19  Wednesday   10/7                   Video
# ...
